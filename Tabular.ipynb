# %%
import numpy as np
import pandas as pd

# %%
# Training set
train=pd.read_csv('train.csv')
train.head(5)
# Out:
#    id product_code  loading attribute_0 attribute_1  attribute_2  attribute_3  \
# 0   0            A    80.10  material_7  material_8            9            5
# 1   1            A    84.89  material_7  material_8            9            5
# 2   2            A    82.43  material_7  material_8            9            5
# 3   3            A   101.07  material_7  material_8            9            5
# 4   4            A   188.06  material_7  material_8            9            5
#
#    measurement_0  measurement_1  measurement_2  ...  measurement_9  \
# 0              7              8              4  ...         10.672
# 1             14              3              3  ...         12.448
# 2             12              1              5  ...         12.715
# 3             13              2              6  ...         12.471
# 4              9              2              8  ...         10.337
#
#    measurement_10  measurement_11  measurement_12  measurement_13  \
# ...

# %%
# Testing set
test=pd.read_csv('test.csv')
test.head(5)
# Out:
#       id product_code  loading attribute_0 attribute_1  attribute_2  \
# 0  26570            F   119.57  material_5  material_6            6
# 1  26571            F   113.51  material_5  material_6            6
# 2  26572            F   112.16  material_5  material_6            6
# 3  26573            F   112.72  material_5  material_6            6
# 4  26574            F   208.00  material_5  material_6            6
#
#    attribute_3  measurement_0  measurement_1  measurement_2  ...  \
# 0            4              6              9              6  ...
# 1            4             11              8              0  ...
# 2            4              8             12              4  ...
# 3            4              8             11             10  ...
# 4            4             14             16              8  ...
#
#    measurement_8  measurement_9  measurement_10  measurement_11  \
# 0         18.654         10.802          15.909          18.070
# ...

# %%
# Splitting of datasets.
x_train,y_train=train.drop(columns=['failure']),train['failure']
x_test=test.copy()

# %%
# Drop
x_train.drop(columns=['id'],inplace=True)
x_test.drop(columns=['id'],inplace=True)

# %%
# data preprocessing
col=['attribute_0', 'attribute_1']

# %%
# Encoding
from feature_engine.encoding import WoEEncoder,RareLabelEncoder
re=RareLabelEncoder(variables=list(col))
re.fit_transform(x_train)
re.transform(x_train)
re.transform(x_test)
we=WoEEncoder(variables=list(col))
we.fit(x_train,y_train)
# Transform
x_train=we.transform(x_train)
x_test=we.transform(x_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\feature_engine\encoding\rare_label.py:178: UserWarning: The number of unique categories for variable attribute_0 is less than that indicated in n_categories. Thus, all categories will be considered frequent
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\feature_engine\encoding\rare_label.py:178: UserWarning: The number of unique categories for variable attribute_1 is less than that indicated in n_categories. Thus, all categories will be considered frequent
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\feature_engine\encoding\base_encoder.py:238: UserWarning: During the encoding, NaN values were introduced in the feature(s) attribute_1.
#   warnings.warn(

# %%
from sklearn.preprocessing import OrdinalEncoder,LabelEncoder
oe=LabelEncoder()
x_train['product_code']=oe.fit_transform(x_train['product_code'])

# %%
x_test['product_code']=oe.fit_transform(x_test['product_code'])

# %%
# data preprocessing
train.isnull().sum()/len(train)*100
# Out:
# id                0.000000
# product_code      0.000000
# loading           0.940911
# attribute_0       0.000000
# attribute_1       0.000000
# attribute_2       0.000000
# attribute_3       0.000000
# measurement_0     0.000000
# measurement_1     0.000000
# measurement_2     0.000000
# measurement_3     1.433948
# measurement_4     2.024840
# measurement_5     2.544223
# measurement_6     2.995860
# measurement_7     3.526534
# measurement_8     3.944298
# measurement_9     4.617990
# measurement_10    4.892736
# measurement_11    5.525028
# measurement_12    6.025593
# measurement_13    6.676703
# measurement_14    7.053067
# measurement_15    7.561159
# measurement_16    7.941287
# measurement_17    8.596161
# failure           0.000000
# dtype: float64

# %%
# Handling of null values
from sklearn.impute import KNNImputer
knn_null=KNNImputer()
knn_null.fit_transform(x_train)
# Out:
# array([[0.00000000e+00, 8.01000000e+01, 1.78938003e-02, ...,
#         1.30340000e+01, 1.46840000e+01, 7.64100000e+02],
#        [0.00000000e+00, 8.48900000e+01, 1.78938003e-02, ...,
#         1.43950000e+01, 1.56310000e+01, 6.82057000e+02],
#        [0.00000000e+00, 8.24300000e+01, 1.78938003e-02, ...,
#         1.40940000e+01, 1.79460000e+01, 6.63376000e+02],
#        ...,
#        [4.00000000e+00, 1.15620000e+02, 1.78938003e-02, ...,
#         1.55900000e+01, 1.40650000e+01, 7.50364000e+02],
#        [4.00000000e+00, 1.06380000e+02, 1.78938003e-02, ...,
#         1.36240000e+01, 1.28650000e+01, 7.30156000e+02],
#        [4.00000000e+00, 1.31200000e+02, 1.78938003e-02, ...,
#         1.65270000e+01, 1.78900000e+01, 6.02354000e+02]])

# %%
# Dealing with null values
x_train=pd.DataFrame(data=knn_null.fit_transform(x_train),columns=x_train.columns)

# %%
x_test=pd.DataFrame(data=knn_null.transform(x_test),columns=x_test.columns)

# %%
col=['loading', 'attribute_2',
       'attribute_3', 'measurement_0', 'measurement_1', 'measurement_2',
       'measurement_3', 'measurement_4', 'measurement_5', 'measurement_6',
       'measurement_7', 'measurement_8', 'measurement_9', 'measurement_10',
       'measurement_11', 'measurement_12', 'measurement_13', 'measurement_14',
       'measurement_15', 'measurement_16', 'measurement_17']

# %%
# Transformer
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
for i in col:
    x_train[i]=pt.fit_transform(x_train[[i]])
    x_test[i]=pt.transform(x_test[[i]])

# %%
# Prepare for Model building
x_train.head(5)
x_test.head(5)
# Out:
#    product_code   loading  attribute_0  attribute_1  attribute_2  attribute_3  \
# 0           0.0 -0.074806     -0.07464    -0.033831    -0.385536    -1.858746
# 1           0.0 -0.250143     -0.07464    -0.033831    -0.385536    -1.858746
# 2           0.0 -0.290489     -0.07464    -0.033831    -0.385536    -1.858746
# 3           0.0 -0.273693     -0.07464    -0.033831    -0.385536    -1.858746
# 4           0.0  1.785337     -0.07464    -0.033831    -0.385536    -1.858746
#
#    measurement_0  measurement_1  measurement_2  measurement_3  ...  \
# 0      -0.232034       0.263639       0.028640       1.520890  ...
# 1       0.902949       0.032902      -2.479225       0.092953  ...
# 2       0.257227       0.910242      -0.618700       0.687500  ...
# 3       0.257227       0.701400       1.112643      -1.278347  ...
# 4       1.475795       1.693171       0.597626       0.017622  ...
#
#    measurement_8  measurement_9  measurement_10  measurement_11  \
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PowerTransformer
from sklearn.feature_selection import RFE,SelectFromModel
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression

# %%
# Model builidng.
linreg=LogisticRegression()
linreg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
# Predict
y_pred=linreg.predict(x_test)

# %%
sample=pd.read_csv('sample_submission.csv')
sample['failure']=y_pred

# %%
sample['failure'].value_counts()
# Out:
# 0    20775
# Name: failure, dtype: int64

# %%
my_submission=pd.read_csv('my_submiss')
my_submission.drop(columns=['Unnamed: 0'],inplace=True)

# %%
# With pipeline
pipe = Pipeline((("pt",PowerTransformer()),("lr", GradientBoostingClassifier()),))

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('pt', PowerTransformer()),
#                 ('lr', GradientBoostingClassifier())])

# %%
y_pred=pipe.predict(x_test)

# %% [raw]
# #With Pipeline
# import warnings
# warnings.filterwarnings('ignore')
# from sklearn.pipeline import Pipeline
# from sklearn.preprocessing import PowerTransformer
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.ensemble import GradientBoostingRegressor
# X=demo.drop('csMPa',axis=1)
# y=demo[['csMPa']]
# Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size= .20,random_state=10)
# pipe = Pipeline((
# #("pt",PowerTransformer()),
# ("lr", GradientBoostingRegressor(n_estimators=1500)),
# ))
# pipe.fit(Xtrain,ytrain)
# print("Training R2")
# print(pipe.score(Xtrain,ytrain))
# print("Testing R2")
# print(pipe.score(Xtest,ytest))
# scoresdt = cross_val_score(pipe,Xtrain,ytrain,cv=10)
# print(scoresdt)
# print("Average R2")
# print(np.mean(scoresdt))
